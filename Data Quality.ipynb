# %%
import pandas as pd
import great_expectations as ge

# %%
df = ge.read_csv(r'C:\Users\15512\Desktop\New folder\activities.csv')

# %%
df.head()
# Out:
#    Activity ID              Activity Date                       Activity Name  \
# 0    720562793  Sep 21, 2016, 11:47:58 PM                       Afternoon Run
# 1   2223302257  Mar 18, 2019, 11:21:14 PM                   Sunny Foot Gaurds
# 2   2228322663  Mar 21, 2019, 12:00:04 AM                   Sunny gaurds foot
# 3   2261159302    Apr 3, 2019, 1:11:19 AM  Extended guard foot sunny 5k racer
# 4   2263517705    Apr 4, 2019, 1:08:02 AM                           Hill slc
#
#   Activity Type              Activity Description  Elapsed Time  Distance  \
# 0           Run                               NaN          1310      3.31
# 1           Run                               NaN          1315      3.92
# 2           Run  Wind was strong. Made it harder           1291      3.93
# 3           Run                               NaN          1555      5.09
# 4           Run                               NaN          1606      3.06
#
#    Max Heart Rate  Relative Effort  Commute  ...  Weather Ozone  \
# 0             NaN              NaN    False  ...            NaN
# 1             NaN              NaN    False  ...            NaN
# 2             NaN              NaN    False  ...            NaN
# 3             NaN              NaN    False  ...            NaN
# 4             NaN              NaN    False  ...            NaN
#
#   <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.jump_count">Jump Count</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.total_grit">Total Grit</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_flow">Avg Flow</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.flagged">Flagged</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_elapsed_speed">Avg Elapsed Speed</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.dirt_distance">Dirt Distance</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_distance">Newly Explored Distance</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_dirt_distance">Newly Explored Dirt Distance</span>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.sport_type">Sport Type</span>
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 84 columns]

# %%
df.columns
# Out:
# Index(['Activity ID', 'Activity Date', 'Activity Name', 'Activity Type',
#        'Activity Description', 'Elapsed Time', 'Distance', 'Max Heart Rate',
#        'Relative Effort', 'Commute', 'Activity Gear', 'Filename',
#        'Athlete Weight', 'Bike Weight', 'Elapsed Time.1', 'Moving Time',
#        'Distance.1', 'Max Speed', 'Average Speed', 'Elevation Gain',
#        'Elevation Loss', 'Elevation Low', 'Elevation High', 'Max Grade',
#        'Average Grade', 'Average Positive Grade', 'Average Negative Grade',
#        'Max Cadence', 'Average Cadence', 'Max Heart Rate.1',
#        'Average Heart Rate', 'Max Watts', 'Average Watts', 'Calories',
#        'Max Temperature', 'Average Temperature', 'Relative Effort.1',
#        'Total Work', 'Number of Runs', 'Uphill Time', 'Downhill Time',
#        'Other Time', 'Perceived Exertion',
#        '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.type">Type</span>',
#        '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.start_time">Start Time</span>',
#        'Weighted Average Power', 'Power Count', 'Prefer Perceived Exertion',
#        'Perceived Relative Effort', 'Commute.1', 'Total Weight Lifted',
#        'From Upload', 'Grade Adjusted Distance', 'Weather Observation Time',
#        'Weather Condition', 'Weather Temperature', 'Apparent Temperature',
#        'Dewpoint', 'Humidity', 'Weather Pressure', 'Wind Speed', 'Wind Gust',
#        'Wind Bearing', 'Precipitation Intensity', 'Sunrise Time',
#        'Sunset Time', 'Moon Phase', 'Bike', 'Gear',
#        'Precipitation Probability', 'Precipitation Type', 'Cloud Cover',
#        'Weather Visibility', 'UV Index', 'Weather Ozone',
#        '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.jump_count">Jump Count</span>',
#        '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.total_grit">Total Grit</span>',
#        '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_flow">Avg Flow</span>',
#        '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.flagged">Flagged</span>',
#        '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_elapsed_speed">Avg Elapsed Speed</span>',
#        '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.dirt_distance">Dirt Distance</span>',
#        '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_distance">Newly Explored Distance</span>',
#        '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_dirt_distance">Newly Explored Dirt Distance</span>',
#        '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.sport_type">Sport Type</span>'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Activity ID   Elapsed Time    Distance  Max Heart Rate  \
# count  4.230000e+02     423.000000  423.000000      108.000000
# mean   5.391969e+09    4790.404255    6.327754      156.240741
# std    1.059041e+09   12200.325507    6.440984       25.953902
# min    7.205628e+08     233.000000    0.000000      104.000000
# 25%    4.722557e+09    1685.500000    2.335000      131.750000
# 50%    5.320242e+09    2491.000000    4.210000      164.500000
# 75%    6.018438e+09    3573.500000    8.370000      175.000000
# max    7.512709e+09  173924.000000   59.650000      202.000000
#
#        Relative Effort  Activity Gear  Athlete Weight  Bike Weight  \
# count       108.000000            0.0            16.0          0.0
# mean         56.314815            NaN             0.0          NaN
# std          96.653408            NaN             0.0          NaN
# min           1.000000            NaN             0.0          NaN
# 25%           6.000000            NaN             0.0          NaN
# 50%          19.000000            NaN             0.0          NaN
# 75%          57.000000            NaN             0.0          NaN
# max         656.000000            NaN             0.0          NaN
#
#        Elapsed Time.1   Moving Time  ...  Weather Ozone  \
# count      421.000000    423.000000  ...      27.000000
# mean      4804.327791   2694.215130  ...     342.285185
# std      12227.593057   2550.485202  ...      29.850006
# min        233.000000     64.000000  ...     291.000000
# 25%       1686.000000   1402.500000  ...     319.250000
# 50%       2494.000000   2128.000000  ...     340.200012
# 75%       3583.000000   2876.000000  ...     367.500000
# max     173924.000000  24751.000000  ...     410.700012
#
#        <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.jump_count">Jump Count</span>  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.total_grit">Total Grit</span>  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_flow">Avg Flow</span>  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.flagged">Flagged</span>  \
# count                                         120.000000
# mean                                            0.016667
# std                                             0.182574
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             2.000000
#
#        <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_elapsed_speed">Avg Elapsed Speed</span>  \
# count                                         173.000000
# mean                                            2.126600
# std                                             1.321362
# min                                             0.061949
# 25%                                             1.095721
# 50%                                             1.782417
# 75%                                             2.578162
# max                                             5.539650
#
#        <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.dirt_distance">Dirt Distance</span>  \
# count                                          94.000000
# mean                                         1330.015969
# std                                          3186.451333
# min                                             0.000000
# 25%                                             0.000000
# 50%                                           187.200005
# 75%                                           804.799988
# max                                         24470.800781
#
#        <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_distance">Newly Explored Distance</span>  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_dirt_distance">Newly Explored Dirt Distance</span>  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.sport_type">Sport Type</span>
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
# [8 rows x 78 columns]

# %%
df.tail()
# Out:
#      Activity ID              Activity Date             Activity Name  \
# 418   7433100637    Jul 8, 2022, 1:30:08 AM         Ride with hakeszz
# 419   7437963949    Jul 9, 2022, 1:24:08 AM          Deer Creek Trail
# 420   7454254073   Jul 12, 2022, 1:31:31 AM    Canal ride with Haley
# 421   7496618442  Jul 19, 2022, 10:49:09 PM    Canal ride with Haley
# 422   7512708707   Jul 23, 2022, 2:10:03 AM  First hike after plants
#
#     Activity Type Activity Description  Elapsed Time  Distance  \
# 418          Ride                  NaN          2619     12.94
# 419          Ride                  NaN          7697     24.57
# 420          Ride                  NaN          2292     10.70
# 421          Ride                  NaN          1850      9.44
# 422          Hike          Still hurts          1877      1.54
#
#      Max Heart Rate  Relative Effort  Commute  ...  Weather Ozone  \
# 418             NaN              NaN    False  ...            NaN
# 419             NaN              NaN    False  ...            NaN
# 420             NaN              NaN    False  ...            NaN
# 421             NaN              NaN    False  ...            NaN
# 422             NaN              NaN    False  ...            NaN
#
#     <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.jump_count">Jump Count</span>  \
# 418                                                NaN
# 419                                                NaN
# 420                                                NaN
# 421                                                NaN
# 422                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.total_grit">Total Grit</span>  \
# 418                                                NaN
# 419                                                NaN
# 420                                                NaN
# 421                                                NaN
# 422                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_flow">Avg Flow</span>  \
# 418                                                NaN
# 419                                                NaN
# 420                                                NaN
# 421                                                NaN
# 422                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.flagged">Flagged</span>  \
# 418                                                0.0
# 419                                                0.0
# 420                                                0.0
# 421                                                0.0
# 422                                                0.0
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_elapsed_speed">Avg Elapsed Speed</span>  \
# 418                                           4.941405
# 419                                           3.193160
# 420                                           4.668756
# 421                                           5.103211
# 422                                           0.820858
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.dirt_distance">Dirt Distance</span>  \
# 418                                           0.000000
# 419                                       24470.800781
# 420                                          35.900002
# 421                                           0.000000
# 422                                        1540.800049
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_distance">Newly Explored Distance</span>  \
# 418                                                NaN
# 419                                                NaN
# 420                                                NaN
# 421                                                NaN
# 422                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_dirt_distance">Newly Explored Dirt Distance</span>  \
# 418                                                NaN
# 419                                                NaN
# 420                                                NaN
# 421                                                NaN
# 422                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.sport_type">Sport Type</span>
# 418                                                NaN
# 419                                                NaN
# 420                                                NaN
# 421                                                NaN
# 422                                                NaN
#
# [5 rows x 84 columns]

# %%
# Is Activity ID unique 

df.expect_column_values_to_be_unique(column="Activity ID")
# Out:
# {
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "result": {
#     "element_count": 423,
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0,
#     "partial_unexpected_list": []
#   },
#   "success": true
# }

# %%
# Is the activity type one of the following?
# Bike Hike Walk Run 
activities = ['Run', 'Hike', 'Walk','Bike']
df.expect_column_values_to_be_in_set('Activity Type',
        value_set = activities)
# Out:
# {
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "result": {
#     "element_count": 423,
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_count": 122,
#     "unexpected_percent": 28.841607565011824,
#     "unexpected_percent_total": 28.841607565011824,
#     "unexpected_percent_nonmissing": 28.841607565011824,
#     "partial_unexpected_list": [
#       "Stand Up Paddling",
#       "Stand Up Paddling",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride",
#       "Ride"
#     ]
#   },
#   "success": false
# }

# %%
# Is the max speed lower than 25? 
df.expect_column_values_to_be_between('Max Speed',0,12)
# Out:
# {
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   },
#   "result": {
#     "element_count": 423,
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_count": 43,
#     "unexpected_percent": 10.16548463356974,
#     "unexpected_percent_total": 10.16548463356974,
#     "unexpected_percent_nonmissing": 10.16548463356974,
#     "partial_unexpected_list": [
#       17.600000381469727,
#       12.5,
#       18.200000762939453,
#       17.899999618530273,
#       12.100000381469728,
#       15.800000190734863,
#       19.200000762939453,
#       13.399999618530272,
#       12.899999618530272,
#       12.300000190734863,
#       12.100000381469728,
#       34.29999923706055,
#       13.800000190734863,
#       12.199999809265137,
#       20.100000381469727,
#       31.399999618530277,
#       14.0,
#       16.700000762939453,
#       17.700000762939453,
#       13.800000190734863
#     ]
#   },
#   "success": false
# }
